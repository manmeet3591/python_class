# %% [markdown]
# Following http://pure.iiasa.ac.at/id/eprint/14952/1/xarray-tutorial-egu2017-answers.pdf

# %%
import xarray as xr
import numpy as np
import pandas as pd
import netCDF4
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# %%
data_dir = '/lus/dal/cccr_rnd/manmeet/deepsd/data/prism/ppt/raw/prism_ppt_4km2_2014.nc'
ds = xr.open_dataset(data_dir)

# %%
ds.ppt[:100,0,0]==np.nan
# Out:
# <xarray.DataArray 'ppt' (time: 100)>
# array([False, False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False, False])
# Coordinates:
#     lon      float64 -125.0
#     lat      float64 49.94
#   * time     (time) datetime64[ns] 2014-01-01 2014-01-02 ... 2014-04-10

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 621, lon: 1405, time: 365)
# Coordinates:
#   * lon      (lon) float64 -125.0 -125.0 -124.9 -124.9 ... -66.6 -66.56 -66.52
#   * lat      (lat) float64 49.94 49.9 49.85 49.81 ... 24.23 24.19 24.15 24.1
#   * time     (time) datetime64[ns] 2014-01-01 2014-01-02 ... 2014-12-31
# Data variables:
#     ppt      (time, lat, lon) float32 ...

# %%
ds.ppt.values
# Out:
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        ...,
#
#        [[nan, nan, nan, ..., nan, nan, nan],
# ...

# %%
ds.ppt.data
# Out:
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        ...,
#
#        [[nan, nan, nan, ..., nan, nan, nan],
# ...

# %%
ds.ppt.coords
# Out:
# Coordinates:
#   * lon      (lon) float64 -125.0 -125.0 -124.9 -124.9 ... -66.6 -66.56 -66.52
#   * lat      (lat) float64 49.94 49.9 49.85 49.81 ... 24.23 24.19 24.15 24.1
#   * time     (time) datetime64[ns] 2014-01-01 2014-01-02 ... 2014-12-31

# %%
ds.ppt.coords['lon'][0]
# Out:
# <xarray.DataArray 'lon' ()>
# array(-125.020833)
# Coordinates:
#     lon      float64 -125.0

# %%
ds.ppt.coords['lon'][0]
# Out:
# <xarray.DataArray 'lon' ()>
# array(-125.020833)
# Coordinates:
#     lon      float64 -125.0

# %%
ds.ppt.dims
# Out:
# ('time', 'lat', 'lon')

# %%
ds.ppt.dims[0]
# Out:
# 'time'

# %%
ds.time.attrs
# Out:
# OrderedDict()

# %%
ds.time
# Out:
# <xarray.DataArray 'time' (time: 365)>
# array(['2014-01-01T00:00:00.000000000', '2014-01-02T00:00:00.000000000',
#        '2014-01-03T00:00:00.000000000', ..., '2014-12-29T00:00:00.000000000',
#        '2014-12-30T00:00:00.000000000', '2014-12-31T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2014-01-01 2014-01-02 ... 2014-12-31

# %%
ds.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	lat = 621 ;
# 	lon = 1405 ;
# 	time = 365 ;
#
# variables:
# 	float64 lon(lon) ;
# 	float64 lat(lat) ;
# 	float32 ppt(time, lat, lon) ;
# 	datetime64[ns] time(time) ;
#
# // global attributes:
# }

# %%
data_dir = 'new.nc'
ds.to_netcdf(data_dir)

# %%
url ='new.nc'
ds = xr.open_dataset(url, decode_times=False)

# %%
ds.ppt.attrs
# Out:
# OrderedDict()

# %%
ds.time.attrs
# Out:
# OrderedDict([('units', 'days since 2014-01-01'),
#              ('calendar', 'proleptic_gregorian')])

# %%
encoding = {'lat': {'zlib': False, '_FillValue': False},
            'lon': {'zlib': False, '_FillValue': False},
            'ppt': {'_FillValue': -999.0,
                  'chunksizes': (1, 8, 10),
                  'complevel': 1,
                  'zlib': True}
            }
ds.to_netcdf('test.nc', encoding=encoding)

# %%
# So basically _Fillvalue can be played with at the time of writing the file, 
# if we done give any _FillValue xarray automatically picks up nan

# %%
ds = xr.tutorial.load_dataset('air_temperature')
# Out:
# /lus/dal/cccr_rnd/manmeet/anaconda3/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: load_dataset` will be removed in xarray version 0.12. The current behavior of this function can be achived by using `tutorial.open_dataset(...).load()`.
#   """Entry point for launching an IPython kernel.

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 25, lon: 53, time: 2920)
# Coordinates:
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
# Data variables:
#     air      (time, lat, lon) float32 241.2 242.5 243.5 ... 296.49 296.19 295.69
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %%
ds.air
# Out:
# <xarray.DataArray 'air' (time: 2920, lat: 25, lon: 53)>
# array([[[241.2    , 242.5    , ..., 235.5    , 238.59999],
#         [243.79999, 244.5    , ..., 235.29999, 239.29999],
#         ...,
#         [295.9    , 296.19998, ..., 295.9    , 295.19998],
#         [296.29   , 296.79   , ..., 296.79   , 296.6    ]],
#
#        [[242.09999, 242.7    , ..., 233.59999, 235.79999],
#         [243.59999, 244.09999, ..., 232.5    , 235.7    ],
#         ...,
#         [296.19998, 296.69998, ..., 295.5    , 295.1    ],
#         [296.29   , 297.19998, ..., 296.4    , 296.6    ]],
#
#        ...,
#
#        [[245.79   , 244.79   , ..., 243.98999, 244.79   ],
#         [249.89   , 249.29   , ..., 242.48999, 244.29   ],
#         ...,
#         [296.29   , 297.19   , ..., 295.09   , 294.38998],
#         [297.79   , 298.38998, ..., 295.49   , 295.19   ]],
#
#        [[245.09   , 244.29   , ..., 241.48999, 241.79   ],
#         [249.89   , 249.29   , ..., 240.29   , 241.68999],
#         ...,
# ...

# %%
ds.dims
# Out:
# Frozen(SortedKeysDict({'lon': 53, 'time': 2920, 'lat': 25}))

# %%
ds.attrs
# Out:
# OrderedDict([('Conventions', 'COARDS'),
#              ('title', '4x daily NMC reanalysis (1948)'),
#              ('description',
#               'Data is from NMC initialized reanalysis\n(4x/day).  These are the 0.9950 sigma level values.'),
#              ('platform', 'Model'),
#              ('references',
#               'http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanalysis.html')])

# %%
ds.air.values
# Out:
# array([[[241.2    , 242.5    , 243.5    , ..., 232.79999, 235.5    ,
#          238.59999],
#         [243.79999, 244.5    , 244.7    , ..., 232.79999, 235.29999,
#          239.29999],
#         [250.     , 249.79999, 248.89   , ..., 233.2    , 236.39   ,
#          241.7    ],
#         ...,
#         [296.6    , 296.19998, 296.4    , ..., 295.4    , 295.1    ,
#          294.69998],
#         [295.9    , 296.19998, 296.79   , ..., 295.9    , 295.9    ,
#          295.19998],
#         [296.29   , 296.79   , 297.1    , ..., 296.9    , 296.79   ,
#          296.6    ]],
#
#        [[242.09999, 242.7    , 243.09999, ..., 232.     , 233.59999,
#          235.79999],
#         [243.59999, 244.09999, 244.2    , ..., 231.     , 232.5    ,
#          235.7    ],
#         [253.2    , 252.89   , 252.09999, ..., 230.79999, 233.39   ,
#          238.5    ],
#         ...,
#         [296.4    , 295.9    , 296.19998, ..., 295.4    , 295.1    ,
#          294.79   ],
# ...

# %%
ds.air.values.shape
# Out:
# (2920, 25, 53)

# %%
type(ds.air.values)
# Out:
# numpy.ndarray

# %%
ds.air.dims
# Out:
# ('time', 'lat', 'lon')

# %%
ds.air.attrs
# Out:
# OrderedDict([('long_name', '4xDaily Air temperature at sigma level 995'),
#              ('units', 'degK'),
#              ('precision', 2),
#              ('GRIB_id', 11),
#              ('GRIB_name', 'TMP'),
#              ('var_desc', 'Air temperature'),
#              ('dataset', 'NMC Reanalysis'),
#              ('level_desc', 'Surface'),
#              ('statistic', 'Individual Obs'),
#              ('parent_stat', 'Other'),
#              ('actual_range', array([185.16, 322.1 ], dtype=float32))])

# %%
ds.air.attrs['tutorial-date'] = 25092019

# %%
ds.air.attrs
# Out:
# OrderedDict([('long_name', '4xDaily Air temperature at sigma level 995'),
#              ('units', 'degK'),
#              ('precision', 2),
#              ('GRIB_id', 11),
#              ('GRIB_name', 'TMP'),
#              ('var_desc', 'Air temperature'),
#              ('dataset', 'NMC Reanalysis'),
#              ('level_desc', 'Surface'),
#              ('statistic', 'Individual Obs'),
#              ('parent_stat', 'Other'),
#              ('actual_range', array([185.16, 322.1 ], dtype=float32)),
#              ('tutorial-date', 25092019)])

# %%
kelvin = ds.air.mean(dim='time')

# %%
kelvin.plot();

# %%
centigrade = kelvin - 273.16

# %%
centigrade.plot();

# %%
np.sin(centigrade).plot();

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 25, lon: 53, time: 2920)
# Coordinates:
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
# Data variables:
#     air      (time, lat, lon) float32 241.2 242.5 243.5 ... 296.49 296.19 295.69
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %%
ds['centigrade'] = centigrade

# %%
ds['kelvin'] = kelvin

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (lat: 25, lon: 53, time: 2920)
# Coordinates:
#   * lat         (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon         (lon) float32 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
#   * time        (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
# Data variables:
#     air         (time, lat, lon) float32 241.2 242.5 243.5 ... 296.19 295.69
#     centigrade  (lat, lon) float32 -12.784363 -12.977417 ... 24.121033 24.14502
#     kelvin      (lat, lon) float32 260.37564 260.1826 ... 297.28104 297.30502
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %%
ds.kelvin.attrs
# Out:
# OrderedDict()

# %%
ds.kelvin.attrs['Description'] = 'Mean air tempterature (through time)'

# %%
ds.kelvin
# Out:
# <xarray.DataArray 'kelvin' (lat: 25, lon: 53)>
# array([[260.37564, 260.1826 , 259.88593, ..., 250.81511, 251.93733, 253.43741],
#        [262.7337 , 262.7936 , 262.7489 , ..., 249.75496, 251.5852 , 254.35849],
#        [264.7681 , 264.3271 , 264.0614 , ..., 250.60707, 253.58247, 257.71475],
#        ...,
#        [297.64932, 296.95294, 296.62912, ..., 296.81033, 296.28793, 295.81622],
#        [298.1287 , 297.93646, 297.47006, ..., 296.8591 , 296.77686, 296.44348],
#        [298.36594, 298.38593, 298.11386, ..., 297.33777, 297.28104, 297.30502]],
#       dtype=float32)
# Coordinates:
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
# Attributes:
#     Description:  Mean air tempterature (through time)

# %%
ds.to_netcdf('new_file.nc')
# Out:
# /lus/dal/cccr_rnd/manmeet/anaconda3/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:1: SerializationWarning: saving variable air with floating point data as an integer dtype without any _FillValue to use for NaNs
#   """Entry point for launching an IPython kernel.

# %%
ds.air[:, 1, 2]
# Out:
# <xarray.DataArray 'air' (time: 2920)>
# array([244.7    , 244.2    , 244.     , ..., 248.59   , 248.48999, 248.39   ],
#       dtype=float32)
# Coordinates:
#     lat      float32 72.5
#     lon      float32 205.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
# Attributes:
#     long_name:      4xDaily Air temperature at sigma level 995
#     units:          degK
#     precision:      2
#     GRIB_id:        11
#     GRIB_name:      TMP
#     var_desc:       Air temperature
#     dataset:        NMC Reanalysis
#     level_desc:     Surface
#     statistic:      Individual Obs
#     parent_stat:    Other
#     actual_range:   [185.16 322.1 ]
#     tutorial-date:  25092019

# %%
ds.air[:, 1, 2].plot();

# %%
ds.air.isel(time=0).plot(); # like above, but with a dimension name this

# %%
ds.air.sel(lat=72.5, lon=205).plot();

# %%
ds.air.sel(time='2013-01-02').plot(); # Note that we will extract 4 time

# %%
ds.air.sel(time='2013-01-02T06:00').plot();

# %%
ds.air.sel(lat=slice(60, 50), lon=slice(200, 270), time='2013-01-02T06:00').plot()

# %%
ds.air.sel(lat=41.8781, lon=360-87.6298, method='nearest', tolerance=5).plot()

# %%
a = xr.DataArray(np.arange(3), dims='time', coords={'time':np.arange(3)})

# %%
a
# Out:
# <xarray.DataArray (time: 3)>
# array([0, 1, 2])
# Coordinates:
#   * time     (time) int64 0 1 2

# %%
b = xr.DataArray(np.arange(4), dims='space', coords={'space':np.arange(4)})

# %%
b
# Out:
# <xarray.DataArray (space: 4)>
# array([0, 1, 2, 3])
# Coordinates:
#   * space    (space) int64 0 1 2 3

# %%
a + b
# Out:
# <xarray.DataArray (time: 3, space: 4)>
# array([[0, 1, 2, 3],
#        [1, 2, 3, 4],
#        [2, 3, 4, 5]])
# Coordinates:
#   * time     (time) int64 0 1 2
#   * space    (space) int64 0 1 2 3

# %%
ds.max()
# Out:
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     air         float32 317.4
#     centigrade  float32 28.485992
#     kelvin      float32 301.646

# %%
ds.air.median(dim=['lat', 'lon']).plot();

# %%
means = ds.air.mean(dim=['time'])

# %%
means.where(means > 273.15).plot();

# %%
ds.air.groupby('time.season').mean()
# Out:
# /lus/dal/cccr_rnd/manmeet/anaconda3/envs/py35/lib/python3.5/site-packages/xarray/core/groupby.py:631: FutureWarning: Default reduction dimension will be changed to the grouped dimension after xarray 0.12. To silence this warning, pass dim=xarray.ALL_DIMS explicitly.
#   skipna=skipna, allow_lazy=True, **kwargs)
# <xarray.DataArray 'air' (season: 4)>
# array([273.64966, 289.20493, 278.99133, 283.02805], dtype=float32)
# Coordinates:
#   * season   (season) object 'DJF' 'JJA' 'MAM' 'SON'

# %%
ds.air.groupby('time.month').mean('time')
# Out:
# <xarray.DataArray 'air' (month: 12, lat: 25, lon: 53)>
# array([[[246.34987, 246.38608, ..., 244.08795, 245.6467 ],
#         [248.8576 , 248.90733, ..., 243.50865, 246.75471],
#         ...,
#         [296.5446 , 296.46982, ..., 295.0812 , 294.53006],
#         [297.15417, 297.2383 , ..., 295.77554, 295.63647]],
#
#        [[246.67715, 246.40576, ..., 243.0021 , 244.44383],
#         [247.8001 , 247.75992, ..., 242.26633, 245.06662],
#         ...,
#         [296.78754, 296.63443, ..., 294.2178 , 293.70258],
#         [297.2889 , 297.2165 , ..., 294.9558 , 294.87967]],
#
#        ...,
#
#        [[253.74484, 253.64487, ..., 243.9345 , 245.14209],
#         [259.12967, 258.62927, ..., 243.07965, 245.46625],
#         ...,
#         [298.58783, 298.42026, ..., 298.19397, 297.9083 ],
#         [298.81143, 298.8566 , ..., 298.7519 , 298.8189 ]],
#
#        [[247.971  , 248.02118, ..., 241.02383, 242.62823],
#         [249.73361, 250.16037, ..., 240.96469, 244.11626],
#         ...,
# ...

# %%
clim = ds.air.groupby('time.month').mean('time')

# %%
anomalies = ds.air.groupby('time.month') - clim

# %%
anomalies
# Out:
# <xarray.DataArray 'air' (time: 2920, lat: 25, lon: 53)>
# array([[[ -5.149872,  -3.886078, ...,  -8.587952,  -7.046707],
#         [ -5.057617,  -4.407333, ...,  -8.208664,  -7.454727],
#         ...,
#         [ -0.644592,  -0.269836, ...,   0.818787,   0.669922],
#         [ -0.864166,  -0.448303, ...,   1.014465,   0.963531]],
#
#        [[ -4.249878,  -3.686081, ..., -10.487961,  -9.84671 ],
#         [ -5.257614,  -4.807343, ..., -11.008652, -11.054718],
#         ...,
#         [ -0.344604,   0.230164, ...,   0.418793,   0.569946],
#         [ -0.864166,  -0.03833 , ...,   0.624451,   0.963531]],
#
#        ...,
#
#        [[ -2.181   ,  -3.231186, ...,   2.966156,   2.161758],
#         [  0.156387,  -0.870377, ...,   1.525299,   0.173737],
#         ...,
#         [ -1.178131,  -0.190247, ...,  -1.756683,  -2.131348],
#         [ -0.090881,   0.403198, ...,  -2.0755  ,  -2.347626]],
#
#        [[ -2.880997,  -3.731186, ...,   0.466156,  -0.838242],
# ...

# %%
anomalies.plot();

# %%
anomalies.sel(time= '2013-02').plot(); # Find all the anomolous values fo

# %%
zonal_t_average = ds.air.mean(dim=['lon', 'time']) - 273.15

# %%
zonal_t_average
# Out:
# <xarray.DataArray 'air' (lat: 25)>
# array([-15.327881, -14.207825, -12.539459,  -9.669983,  -6.627533,  -4.388672,
#         -1.594879,   0.545197,   1.870544,   3.176483,   5.074066,   7.351013,
#          9.027618,  11.244415,  13.590881,  15.631012,  17.61148 ,  19.273682,
#         20.749939,  21.782166,  22.60669 ,  23.31546 ,  23.984253,  24.70758 ,
#         25.439484], dtype=float32)
# Coordinates:
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0

# %%
zonal_t_average.plot(); # 1D arrays are plotted as line plots

# %%
t_average = ds.air.mean(dim='time') - 273.15
t_average.plot(); # 2D arrays are plotted with pcolormesh

# %%
t_average.plot.contourf(); # but you can use contour(), contourf() or im

# %%
t_average.plot.contourf(cmap='BrBG_r', vmin=-15, vmax=15);

# %%
t_average.plot.contourf(cmap='BrBG_r', levels=22, center=False);

# %%
air_outliers = ds.air.isel(time=0).copy()
air_outliers[0, 0] = 100
air_outliers[-1, -1] = 400
air_outliers.plot(); # outliers mess with the datarange and colorscale!

# %%
air_outliers.plot(robust=True);

# %%
t_season = ds.air.groupby('time.season').mean(dim='time') - 273.15

# %%
t_season.plot.contourf(x='lon', y='lat', col='season', col_wrap=2)

# %%
import cartopy.crs as ccrs
from matplotlib.axes import Axes
from cartopy.mpl.geoaxes import GeoAxes
GeoAxes._pcolormesh_patched = Axes.pcolormesh

# %%
f = plt.figure(figsize=(8, 4))
# Define the map projection *on which* you want to plot
ax = plt.axes(projection=ccrs.Orthographic(-80, 35))
# ax is an empty plot. We now plot the variable t_average onto ax
# the keyword "transform" tells the function in which projection the air temp data is stored
t_average.plot(ax=ax, transform=ccrs.PlateCarree())
# Add gridlines and coastlines to the plot
ax.coastlines(); ax.gridlines();

# %%
p = t_season.plot(x='lon', y='lat', col='season', transform=ccrs.PlateCarree(),
subplot_kws={'projection': ccrs.Orthographic(-80, 35)})
for ax in p.axes.flat:
    ax.coastlines()
